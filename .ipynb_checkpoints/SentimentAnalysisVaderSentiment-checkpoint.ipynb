# %%
import pandas as pd
import numpy as np
import string
import re
from langdetect import detect
import os

# %%
class MovieSentiment:
    def __init__(self, name):
        self.movie_name = name
        self.pos = 0
        self.n = 0
        self.neg = 0
        self.tweets = 0
    
    def print_summary(self):
        print("Movie:", self.movie_name, "| Tweets analysed:", self.tweets,  "| Postive:", self.pos, "| Negative:", self.neg, "| Neutral:", self.n)
    
movies = []
movie_class = {}

# %%
def cleanup(tweet):
    s = re.sub(r'@\S+', '', tweet)
    s = re.sub(r'http\S+', '', s)
    return s

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
 
def sentiment_scores(sentence):
    try:
        sid_obj = SentimentIntensityAnalyzer()
        
        sentiment_dict = sid_obj.polarity_scores(sentence)
        overall_sent = 0

        if sentiment_dict['compound'] >= 0.05 :
            #print("Positive")
            overall_sent = 1
        elif sentiment_dict['compound'] <= - 0.05 :
            #print("Negative")
            overall_sent = -1
        else :
            #print("Neutral")
            overall_sent = 0
    except Exception as e:
        print(e)
        return -2
    return overall_sent

# %%
def write_movie_to_file(m_obj, res_file):
    llist=[]
    llist.append([m_obj.movie_name, m_obj.tweets, m_obj.pos, m_obj.n, m_obj.neg])
    df = pd.DataFrame(llist, columns =['Movie', 'Total Tweets', 'Positive Tweets', 'Neutral Tweets', 'Negative Tweets'])
    df.to_csv(res_file, mode='a', index=False, header=False)

def write_first_movie_to_file(m_obj, res_file):
    llist=[]
    llist.append([m_obj.movie_name, m_obj.tweets, m_obj.pos, m_obj.n, m_obj.neg])
    df = pd.DataFrame(llist, columns =['Movie', 'Total Tweets', 'Positive Tweets', 'Neutral Tweets', 'Negative Tweets'])
    df.to_csv(res_file, mode='a', index=False)

# %%
import csv

def sentiment_analysis_and_store(tweets_file, res_file):
    movies = []
    movie_class = {}
    with open(tweets_file, 'r', encoding="ISO-8859-1") as file:
        csvreader = csv.reader(file)
        line_count = 0
        processed_tweets = 0
        for row in csvreader:
            if (len(row) < 5):
                continue
            if line_count < 1:
                line_count+=1
                continue
            movie_name = row[0]
            tweet = row[3]
            tweet = row[3]
            if tweet == "":
                continue;

            if processed_tweets >= 2500 and movie_name in movies:
                continue;
            if movie_name not in movies:
                movie_class[movie_name] = MovieSentiment(movie_name)
                if len(movies) > 1:
                    write_movie_to_file(movie_class[movies[-1]], res_file)
                    processed_tweets = 0
                elif len(movies) == 1:
                    write_first_movie_to_file(movie_class[movies[-1]], res_file)
                    processed_tweets = 0
                movies.append(movie_name)

            try:
                tweet = cleanup(tweet)
                lang = detect(tweet)
                if (lang != 'en'):
                    continue
            except:
                continue
            if tweet == "":
                continue
            
            overall_sent = sentiment_scores(tweet)
            if (overall_sent == -2):
                continue;
            if overall_sent == 1:
                movie_class[movie_name].pos += 1
            elif overall_sent == -1:
                movie_class[movie_name].neg += 1
            elif overall_sent == 0:
                movie_class[movie_name].n += 1
            movie_class[movie_name].tweets += 1
            line_count += 1
            processed_tweets += 1
            if (line_count % 1000 == 0):
                print("Processed tweet: ", line_count, "\n")
    print(f'Processed {line_count - 1} lines.')
    file.close()

# %%
path = 'Twitter'
files = os.listdir(path)

for file in files:
        year = file.split("_")[1].split(".")[0]
        if year in ['2010']:
            file_path = os.path.join(path, file)
            res_filename = "Vader_res_2500_"+year+".csv"
            sentiment_analysis_and_store(file_path, res_filename)
            print("Processing Done For:", file, "\n")
# Out:
# Processed tweet:  1000
#
# Processed tweet:  2000
#
# Processed tweet:  3000
#
# Processed tweet:  4000
#
# Processed tweet:  5000
#
# Processed tweet:  6000
#
# Processed tweet:  7000
#
# Processed tweet:  8000
#
# Processed tweet:  9000
#
# Processed tweet:  10000
#
# Processed tweet:  11000
#
# Processed tweet:  12000
#
# Processed tweet:  13000
#
# Processed tweet:  14000
#
# Processed tweet:  15000
#
# Processed tweet:  16000
#
# Processed tweet:  17000
#
# Processed tweet:  18000
#
# Processed tweet:  19000
#
# Processed tweet:  20000
#
# Processed tweet:  21000
#
# Processed tweet:  22000
#
# Processed tweet:  23000
#
# Processed tweet:  24000
#
# Processed tweet:  25000
#
# Processed tweet:  26000
#
# Processed tweet:  27000
#
# Processed tweet:  28000
#
# Processed tweet:  29000
#
# Processed tweet:  30000
#
# Processed tweet:  31000
#
# Processed tweet:  32000
#
# Processed tweet:  33000
#
# Processed tweet:  34000
#
# Processed tweet:  35000
#
# Processed tweet:  36000
#
# Processed tweet:  37000
#
# Processed tweet:  38000
#
# Processed tweet:  39000
#
# Processed tweet:  40000
#
# Processed tweet:  41000
#
# Processed tweet:  42000
#
# Processed tweet:  43000
#
# Processed tweet:  44000
#
# Processed tweet:  45000
#
# Processed tweet:  46000
#
# Processed tweet:  47000
#
# Processed tweet:  48000
#
# Processed tweet:  49000
#
# Processed tweet:  50000
#
# Processed tweet:  51000
#
# Processed tweet:  52000
#
# Processed tweet:  53000
#
# Processed tweet:  54000
#
# Processed tweet:  55000
#
# Processed tweet:  56000
#
# Processed tweet:  57000
#
# Processed tweet:  58000
#
# Processed tweet:  59000
#
# Processed tweet:  60000
#
# Processed tweet:  61000
#
# Processed tweet:  62000
#
# Processed tweet:  63000
#
# Processed tweet:  64000
#
# Processed tweet:  65000
#
# Processed tweet:  66000
#
# Processed tweet:  67000
#
# Processed tweet:  68000
#
# Processed tweet:  69000
#
# Processed tweet:  70000
#
# Processed tweet:  71000
#
# Processed tweet:  72000
#
# Processed tweet:  73000
#
# Processed tweet:  74000
#
# Processed tweet:  75000
#
# Processed tweet:  76000
#
# Processed tweet:  77000
#
# Processed tweet:  78000
#
# Processed tweet:  79000
#
# Processed tweet:  80000
#
# Processed tweet:  81000
#
# Processed tweet:  82000
#
# Processed tweet:  83000
#
# Processed tweet:  84000
#
# Processed tweet:  85000
#
# Processed tweet:  86000
#
# Processed tweet:  87000
#
# Processed tweet:  88000
#
# Processed tweet:  89000
#
# Processed tweet:  90000
#
# Processed tweet:  91000
#
# Processed tweet:  92000
#
# Processed tweet:  93000
#
# Processed tweet:  94000
#
# Processed tweet:  95000
#
# Processed tweet:  96000
#
# Processed tweet:  97000
#
# Processed tweet:  98000
#
# Processed tweet:  99000
#
# Processed tweet:  100000
#
# Processed tweet:  101000
#
# Processed tweet:  102000
#
# Processed tweet:  103000
#
# Processed tweet:  104000
#
# Processed tweet:  105000
#
# Processed tweet:  106000
#
# Processed tweet:  107000
#
# Processed tweet:  108000
#
# Processed tweet:  109000
#
# Processed tweet:  110000
#
# Processed tweet:  111000
#
# Processed tweet:  112000
#
# Processed tweet:  113000
#
# Processed tweet:  114000
#
# Processed tweet:  115000
#
# Processed tweet:  116000
#
# Processed tweet:  117000
#
# Processed tweet:  118000
#
# Processed tweet:  119000
#
# Processed tweet:  120000
#
# Processed tweet:  121000
#
# Processed tweet:  122000
#
# Processed tweet:  123000
#
# Processed tweet:  124000
#
# Processed tweet:  125000
#
# Processed tweet:  126000
#
# Processed tweet:  127000
#
# Processed tweet:  128000
#
# Processed tweet:  129000
#
# Processed tweet:  130000
#
# Processed tweet:  131000
#
# Processed tweet:  132000
#
# Processed tweet:  133000
#
# Processed tweet:  134000
#
# Processed tweet:  135000
#
# Processed tweet:  136000
#
# Processed tweet:  137000
#
# Processed tweet:  138000
#
# Processed tweet:  139000
#
# Processed tweet:  140000
#
# Processed tweet:  141000
#
# Processed tweet:  142000
#
# Processed tweet:  143000
#
# Processed tweet:  144000
#
# Processed tweet:  145000
#
# Processed tweet:  146000
#
# Processed tweet:  147000
#
# Processed tweet:  148000
#
# Processed tweet:  149000
#
# Processed tweet:  150000
#
# Processed tweet:  151000
#
# Processed tweet:  152000
#
# Processed tweet:  153000
#
# Processed tweet:  154000
#
# Processed tweet:  155000
#
# Processed tweet:  156000
#
# Processed tweet:  157000
#
# Processed tweet:  158000
#
# Processed tweet:  159000
#
# Processed tweet:  160000
#
# Processed tweet:  161000
#
# Processed tweet:  162000
#
# Processed tweet:  163000
#
# Processed tweet:  164000
#
# Processed tweet:  165000
#
# Processed tweet:  166000
#
# Processed tweet:  167000
#
# Processed tweet:  168000
#
# Processed tweet:  169000
#
# Processed tweet:  170000
#
# Processed tweet:  171000
#
# Processed tweet:  172000
#
# Processed tweet:  173000
#
# Processed tweet:  174000
#
# Processed tweet:  175000
#
# Processed tweet:  176000
#
# Processed tweet:  177000
#
# Processed tweet:  178000
#
# Processed tweet:  179000
#
# Processed tweet:  180000
#
# Processed tweet:  181000
#
# Processed tweet:  182000
#
# Processed tweet:  183000
#
# Processed tweet:  184000
#
# Processed tweet:  185000
#
# Processed tweet:  186000
#
# Processed tweet:  187000
#
# Processed tweet:  188000
#
# Processed tweet:  189000
#
# Processed tweet:  190000
#
# Processed tweet:  191000
#
# Processed tweet:  192000
#
# Processed tweet:  193000
#
# Processed tweet:  194000
#
# Processed tweet:  195000
#
# Processed tweet:  196000
#
# Processed tweet:  197000
#
# Processed tweet:  198000
#
# Processed tweet:  199000
#
# Processed tweet:  200000
#
# Processed tweet:  201000
#
# Processed tweet:  202000
#
# Processed tweet:  203000
#
# Processed tweet:  204000
#
# Processed tweet:  205000
#
# Processed tweet:  206000
#
# Processed tweet:  207000
#
# Processed tweet:  208000
#
# Processed tweet:  209000
#
# Processed tweet:  210000
#
# Processed tweet:  211000
#
# Processed tweet:  212000
#
# Processed tweet:  213000
#
# Processed tweet:  214000
#
# Processed tweet:  215000
#
# Processed tweet:  216000
#
# Processed tweet:  217000
#
# Processed tweet:  218000
#
# Processed tweet:  219000
#
# Processed tweet:  220000
#
# Processed tweet:  221000
#
# Processed tweet:  222000
#
# Processed tweet:  223000
#
# Processed tweet:  224000
#
# Processed tweet:  225000
#
# Processed tweet:  226000
#
# Processed tweet:  227000
#
# Processed tweet:  228000
#
# Processed tweet:  229000
#
# Processed tweet:  230000
#
# Processed tweet:  231000
#
# Processed tweet:  232000
#
# Processed tweet:  233000
#
# Processed tweet:  234000
#
# Processed tweet:  235000
#
# Processed tweet:  236000
#
# Processed tweet:  237000
#
# Processed tweet:  238000
#
# Processed tweet:  239000
#
# Processed tweet:  240000
#
# Processed tweet:  241000
#
# Processed tweet:  242000
#
# Processed tweet:  243000
#
# Processed tweet:  244000
#
# Processed tweet:  245000
#
# Processed tweet:  246000
#
# Processed tweet:  247000
#
# Processed tweet:  248000
#
# Processed tweet:  249000
#
# Processed tweet:  250000
#
# Processed tweet:  251000
#
# Processed tweet:  252000
#
# Processed tweet:  253000
#
# Processed tweet:  254000
#
# Processed tweet:  255000
#
# Processed tweet:  256000
#
# Processed tweet:  257000
#
# Processed tweet:  258000
#
# Processed tweet:  259000
#
# Processed tweet:  260000
#
# Processed tweet:  261000
#
# Processed tweet:  262000
#
# Processed tweet:  263000
#
# Processed tweet:  264000
#
# Processed tweet:  265000
#
# Processed tweet:  266000
#
# Processed tweet:  267000
#
# Processed tweet:  268000
#
# Processed tweet:  269000
#
# Processed tweet:  270000
#
# Processed tweet:  271000
#
# Processed tweet:  272000
#
# Processed tweet:  273000
#
# Processed tweet:  274000
#
# Processed tweet:  275000
#
# Processed tweet:  276000
#
# Processed tweet:  277000
#
# Processed tweet:  278000
#
# Processed tweet:  279000
#
# Processed tweet:  280000
#
# Processed tweet:  281000
#
# Processed tweet:  282000
#
# Processed tweet:  283000
#
# Processed tweet:  284000
#
# Processed tweet:  285000
#
# Processed tweet:  286000
#
# Processed tweet:  287000
#
# Processed tweet:  288000
#
# Processed tweet:  289000
#
# Processed tweet:  290000
#
# Processed tweet:  291000
#
# Processed tweet:  292000
#
# Processed tweet:  293000
#
# Processed tweet:  294000
#
# Processed tweet:  295000
#
# Processed tweet:  296000
#
# Processed tweet:  297000
#
# Processed tweet:  298000
#
# Processed tweet:  299000
#
# Processed tweet:  300000
#
# Processed tweet:  301000
#
# Processed tweet:  302000
#
# Processed tweet:  303000
#
# Processed tweet:  304000
#
# Processed tweet:  305000
#
# Processed tweet:  306000
#
# Processed tweet:  307000
#
# Processed tweet:  308000
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /state/partition1/job-18354525/ipykernel_3757740/2597089853.py in <module>
#       7             file_path = os.path.join(path, file)
#       8             res_filename = "Vader_res_2500_"+year+".csv"
# ----> 9             sentiment_analysis_and_store(file_path, res_filename)
#      10             print("Processing Done For:", file, "\n")
#
# /state/partition1/job-18354525/ipykernel_3757740/775363483.py in sentiment_analysis_and_store(tweets_file, res_file)
#       8         line_count = 0
#       9         processed_tweets = 0
# ---> 10         for row in csvreader:
#      11             if (len(row) < 5):
#      12                 continue
#
# Error: line contains NUL
