# %%
from calendar import month
from operator import index
import snscrape.modules.twitter as sntwitter
import pandas as pd
import glob
import datetime

release_dates = pd.read_csv("Release dates - data.csv")
release_dates_map = {}

folderpathrt = "rotten_info/*"
filesrt = []

for file in glob.glob(folderpathrt):
    filesrt.append(file)

for file in filesrt:
    print(file)
    movies = pd.read_csv(file)

    tweets = []
    for ind, movie in movies.iterrows():
        movien = movie['Release Group']
        if not pd.isna(movie['Release Date (Theaters)']):
            release_date = ('').join(movie['Release Date (Theaters)'].strip('[]').split(',')).replace("'", "")
            rd = datetime.datetime.strptime(release_date, "%b %d %Y")
            # if release_dates_map.get(movien.lower(), ''):
            release_dates_map[movien.lower()] = rd

folderpath = "Box Office Mojo/*"
files = []

for file in glob.glob(folderpath):
    files.append(file)

for ind, row in release_dates.iterrows():
    if row['Release-Date']:
        rd = datetime.datetime.strptime(row['Release-Date'], "%Y-%m-%d")
        if not release_dates_map.get(row['Movie'].lower(), None):
            release_dates_map[row['Movie'].lower()] = rd
    
count = 0
c = 0
for file in files:
    if '2016' in file:
        print(file)
        movies = pd.read_csv(file)

        tweets = []
        for ind, movie in movies.iterrows():
            c += 1
            query_txt = movie['Release Group']
            release_date = release_dates_map.get(movie['Release Group'].lower(), None)
            if release_date:
                count += 1
                # rd = datetime.datetime.strptime(release_date, "%Y-%m-%d")
                since = release_date - datetime.timedelta(weeks=4)
                until = release_date + datetime.timedelta(weeks=1)
                query_txt += " since:%s until:%s" % (since.date(), until.date())
                print(movie['Release Group'], release_date.date())

                for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query_txt).get_items()):
                    if i>5000:
                        break
                    tweets.append([movie['Release Group'], tweet.date, tweet.id, tweet.content, tweet.user.username])

        tweets_df = pd.DataFrame(tweets, columns=['Movie Name', 'Datetime', 'Tweet Id', 'Text', 'Username'])
        tweets_df.to_csv("Twitter/tweets_%s" % file.split('/')[1], index=False, escapechar=r'|')
        break
# Out:
# Box Office Mojo/2016.csv
# Captain America: Civil War 2016-05-06
# Rogue One: A Star Wars Story 2016-12-16
# Finding Dory 2016-06-17
# Zootopia 2016-03-04
# The Jungle Book 2016-04-15
# The Secret Life of Pets 2016-07-08
# Batman v Superman: Dawn of Justice 2016-03-25
# Fantastic Beasts and Where to Find Them 2016-11-18
# Deadpool 2016-02-12
# Suicide Squad 2016-08-05
# Doctor Strange 2016-11-04
# Moana 2016-11-23
# Sing 2016-12-21
# The Mermaid 2016-02-19
# X-Men: Apocalypse 2016-05-27
# Kung Fu Panda 3 2016-01-29
# La La Land 2016-12-09
# Warcraft 2016-06-10
# Jason Bourne 2016-07-29
# Ice Age 5: Collision Course 2016-07-22
# Independence Day: Resurgence 2016-06-24
# Your Name. 2017-04-07
# The Legend of Tarzan 2016-07-01
# The Angry Birds Movie 2016-05-20
# Trolls 2016-11-04
# Star Trek Beyond 2016-07-22
# The Great Wall 2017-02-17
# Now You See Me 2 2016-06-10
# The Conjuring 2 2016-06-10
# Resident Evil: The Final Chapter 2017-01-27
# Dangal 2016-12-21
# Passengers 2016-12-21
# Alice Through the Looking Glass 2016-05-27
# Miss Peregrine's Home for Peculiar Children 2016-09-30
# Teenage Mutant Ninja Turtles: Out of the Shadows 2016-06-03
# Sully 2016-09-09
# Assassin's Creed 2016-12-21
# Hidden Figures 2017-12-25
# Ghostbusters 2016-07-15
# Inferno 2016-10-28
# Central Intelligence 2016-06-17
# Bridget Jones's Baby 2016-09-16
# Me Before You 2016-06-03
# London Has Fallen 2016-03-04
# Arrival 2016-11-11
# The BFG 2016-07-01
# Bad Moms 2016-07-29
# Storks 2016-09-23
# Hacksaw Ridge 2016-11-04
# Allegiant 2016-03-18
# The Girl on the Train 2016-10-07
# The Huntsman: Winter's War 2016-04-22
# The Magnificent Seven 2016-09-23
# Jack Reacher: Never Go Back 2016-10-21
# Don't Breathe 2016-08-26
# The Accountant 2016-10-14
# Lights Out 2016-07-22
# Pete's Dragon 2016-08-12
# Sausage Party 2016-08-12
# Lion 2016-11-25
# Mechanic: Resurrection 2016-08-26
# Deepwater Horizon 2016-09-30
# Allied 2016-11-23
# The Shallows 2016-06-24
# The Purge: Election Year 2016-07-01
# Why Him? 2016-12-23
# Office Christmas Party 2016-12-09
# How to Be Single 2016-02-12
# 10 Cloverfield Lane 2016-03-11
# Neighbors 2: Sorority Rising 2016-05-20
# Dirty Grandpa 2016-01-22
# Ben-Hur 2016-08-19
# Money Monster 2016-05-13
# My Big Fat Greek Wedding 2 2016-03-25
# Collateral Beauty 2016-12-16
# Sultan 2016-07-06
# War Dogs 2016-08-19
# Nerve 2016-07-27
# Leap! 2017-02-24
# Ouija: Origin of Evil 2016-10-21
# Underworld: Blood Wars 2017-01-06
# Manchester by the Sea 2016-11-18
# The Boss 2016-04-08
# Mike and Dave Need Wedding Dates 2016-07-08
# Kubo and the Two Strings 2016-08-19
# Boo! A Madea Halloween 2016-10-21
# Miracles from Heaven 2016-03-16
# Moonlight 2016-10-21
# Monster Trucks 2017-01-13
# Fences 2016-12-16
# The Nice Guys 2016-05-20
# Nine Lives 2016-08-05
# Zoolander 2 2016-02-12
# Barbershop: The Next Cut 2016-04-15
# Patriots Day 2017-12-21
# The Finest Hours 2016-01-29
# Florence Foster Jenkins 2016-08-12
# Mother's Day 2016-04-29
# A Monster Calls 2017-12-23
# Risen 2016-02-19
# Eddie the Eagle 2016-02-26
# Blair Witch 2016-09-16
# Café Society 2016-07-15
# Almost Christmas 2016-11-11
# The Witch 2016-02-19
# The Wild Life 2016-09-09
# The Forest 2016-01-08
# Absolutely Fabulous: The Movie 2016-07-22
# Hell or High Water 2016-08-12
# Snowden 2016-09-16
# Eye in the Sky 2016-03-11
# Ae Dil Hai Mushkil 2016-10-28
# Norm of the North 2016-01-15
# When the Bough Breaks 2016-09-09
# Nocturnal Animals 2016-11-18
# Keeping Up with the Joneses 2016-10-21
# Jackie 2016-12-02
# Masterminds 2016-09-30
# The Brothers Grimsby 2016-03-11
# The Light Between Oceans 2016-09-02
# A Beautiful Planet 2016-04-29
# Born in China 2017-04-21
# Race 2016-02-19
# Free State of Jones 2016-06-24
# Whiskey Tango Foxtrot 2016-03-04
# God's Not Dead 2 2016-04-01
# The Founder 2017-01-19
# Bad Santa 2 2016-11-23
# Silence 2017-12-23
# Kevin Hart: What Now? 2016-10-14
# No manches Frida 2016-09-02
# Middle School: The Worst Years of My Life 2016-10-07
# Triple 9 2016-02-26
# Rock Dog 2017-02-24
# The Choice 2016-02-05
