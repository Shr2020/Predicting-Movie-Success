# %%
from calendar import month
from operator import index
import snscrape.modules.twitter as sntwitter
import pandas as pd
import glob
import datetime

release_dates = pd.read_csv("Release dates - data.csv")
release_dates_map = {}

folderpathrt = "rotten_info/*"
filesrt = []

for file in glob.glob(folderpathrt):
    filesrt.append(file)

for file in filesrt:
    print(file)
    movies = pd.read_csv(file)

    tweets = []
    for ind, movie in movies.iterrows():
        movien = movie['Release Group']
        if not pd.isna(movie['Release Date (Theaters)']):
            release_date = ('').join(movie['Release Date (Theaters)'].strip('[]').split(',')).replace("'", "")
            rd = datetime.datetime.strptime(release_date, "%b %d %Y")
            # if release_dates_map.get(movien.lower(), ''):
            release_dates_map[movien.lower()] = rd

folderpath = "Box Office Mojo/*"
files = []

for file in glob.glob(folderpath):
    files.append(file)

for ind, row in release_dates.iterrows():
    if row['Release-Date']:
        rd = datetime.datetime.strptime(row['Release-Date'], "%Y-%m-%d")
        if not release_dates_map.get(row['Movie'].lower(), None):
            release_dates_map[row['Movie'].lower()] = rd
    
count = 0
c = 0
for file in files:
    if '2020' in file:
        print(file)
        movies = pd.read_csv(file)

        tweets = []
        for ind, movie in movies.iterrows():
            c += 1
            query_txt = movie['Release Group']
            release_date = release_dates_map.get(movie['Release Group'].lower(), None)
            if release_date:
                count += 1
                # rd = datetime.datetime.strptime(release_date, "%Y-%m-%d")
                since = release_date - datetime.timedelta(weeks=4)
                until = release_date + datetime.timedelta(weeks=1)
                query_txt += " since:%s until:%s" % (since.date(), until.date())
                print(movie['Release Group'], release_date.date())

                for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query_txt).get_items()):
                    if i>5000:
                        break
                    tweets.append([movie['Release Group'], tweet.date, tweet.id, tweet.content, tweet.user.username])

        tweets_df = pd.DataFrame(tweets, columns=['Movie Name', 'Datetime', 'Tweet Id', 'Text', 'Username'])
        tweets_df.to_csv("Twitter/tweets_%s" % file.split('/')[1], index=False, escapechar=r'|')
        break
# Out:
# Box Office Mojo/2020.csv
# The Eight Hundred 2020-08-28
# Demon Slayer the Movie: Mugen Train 2021-04-23
# Bad Boys for Life 2020-01-17
# Tenet 2020-09-03
# Sonic the Hedgehog 2020-02-14
# Dolittle 2020-01-17
# The Croods 2: A New Age 2020-11-25
# Birds of Prey 2020-02-07
# Wonder Woman 1984 2020-12-25
# The Invisible Man 2020-02-28
# Onward 2020-03-06
# The Call of the Wild 2020-02-21
# The Rescue 2021-10-08
# Vanguard 2020-11-20
# The New Mutants 2020-08-28
# Fantasy Island 2020-02-14
# After We Collided 2020-10-23
# Unhinged 2020-08-14
# Peninsula 2020-08-07
# Monster Hunter 2020-12-18
# Underwater 2020-01-10
# The War with Grandpa 2020-10-09
# Sarileru Neekevvaru 2020-01-10
# Deliver Us from Evil 2014-07-02
# Bloodshot 2020-03-13
# Honest Thief 2020-10-09
# Like a Boss 2020-01-10
# The Witches 2022-12-25
# Scooby-Doo: A New Universe 2021-05-21
# Emma. 2020-02-21
# The Father 2021-02-26
# Gretel & Hansel 2020-01-31
# The Photograph 2020-02-14
# Brahms: The Boy II 2020-02-21
# The Turning 2020-01-24
# Fate/Stay Night: Heaven's Feel - III. Spring Song 2020-11-18
# Promising Young Woman 2020-12-25
# Baaghi 3 2020-03-06
# I Still Believe 2020-03-13
# Freaky 2020-11-13
# The Way Back 2011-01-21
# The Personal History of David Copperfield 2020-08-28
# Come Play 2020-10-30
# News of the World 2020-12-25
# Let Him Go 2020-11-06
# The Hunt 2020-03-13
# Impractical Jokers: The Movie 2020-02-21
# Downhill 2020-02-14
# 100% Wolf 2020-10-09
# Fatale 2020-12-18
# Chhapaak 2020-01-10
# My Boyfriend's Meds 2020-02-21
# Bill & Ted Face the Music 2020-08-28
# The Rhythm Section 2020-01-31
# Panga 2020-01-24
# The SpongeBob Movie: Sponge on the Run 2020-08-14
# The Empty Man 2020-10-23
# The Broken Hearts Gallery 2020-09-11
