# %%
from calendar import month
from operator import index
import snscrape.modules.twitter as sntwitter
import pandas as pd
import glob
import datetime

release_dates = pd.read_csv("Release dates - data.csv")
release_dates_map = {}

folderpathrt = "rotten_info/*"
filesrt = []

for file in glob.glob(folderpathrt):
    filesrt.append(file)

for file in filesrt:
    print(file)
    movies = pd.read_csv(file)

    tweets = []
    for ind, movie in movies.iterrows():
        movien = movie['Release Group']
        if not pd.isna(movie['Release Date (Theaters)']):
            release_date = ('').join(movie['Release Date (Theaters)'].strip('[]').split(',')).replace("'", "")
            rd = datetime.datetime.strptime(release_date, "%b %d %Y")
            # if release_dates_map.get(movien.lower(), ''):
            release_dates_map[movien.lower()] = rd

folderpath = "Box Office Mojo/*"
files = []

for file in glob.glob(folderpath):
    files.append(file)

for ind, row in release_dates.iterrows():
    if row['Release-Date']:
        rd = datetime.datetime.strptime(row['Release-Date'], "%Y-%m-%d")
        if not release_dates_map.get(row['Movie'].lower(), None):
            release_dates_map[row['Movie'].lower()] = rd
    
count = 0
c = 0
for file in files:
    if '2017' in file:
        print(file)
        movies = pd.read_csv(file)

        tweets = []
        for ind, movie in movies.iterrows():
            c += 1
            query_txt = movie['Release Group']
            release_date = release_dates_map.get(movie['Release Group'].lower(), None)
            if release_date:
                count += 1
                # rd = datetime.datetime.strptime(release_date, "%Y-%m-%d")
                since = release_date - datetime.timedelta(weeks=4)
                until = release_date + datetime.timedelta(weeks=1)
                query_txt += " since:%s until:%s" % (since.date(), until.date())
                print(movie['Release Group'], release_date.date())

                for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query_txt).get_items()):
                    if i>5000:
                        break
                    tweets.append([movie['Release Group'], tweet.date, tweet.id, tweet.content, tweet.user.username])

        tweets_df = pd.DataFrame(tweets, columns=['Movie Name', 'Datetime', 'Tweet Id', 'Text', 'Username'])
        tweets_df.to_csv("Twitter/tweets_%s" % file.split('/')[1], index=False, escapechar=r'|')
        break
# Out:
# Box Office Mojo/2017.csv
# Star Wars: Episode VIII - The Last Jedi 2017-12-15
# Beauty and the Beast 2017-03-17
# The Fate of the Furious 2017-04-14
# Despicable Me 3 2017-06-30
# Jumanji: Welcome to the Jungle 2017-12-20
# Spider-Man: Homecoming 2017-07-07
# Wolf Warrior 2 2017-07-28
# Guardians of the Galaxy Vol. 2 2017-05-05
# Thor: Ragnarok 2017-11-03
# Wonder Woman 2017-06-02
# Coco 2017-11-22
# Pirates of the Caribbean: Dead Men Tell No Tales 2017-05-26
# It 2017-09-08
# Justice League 2017-11-17
# Logan 2017-03-03
# Transformers: The Last Knight 2017-06-21
# Kong: Skull Island 2017-03-10
# The Boss Baby 2017-03-31
# Dunkirk 2017-07-21
# War for the Planet of the Apes 2017-07-14
# The Greatest Showman 2017-12-20
# Kingsman: The Golden Circle 2017-09-22
# The Mummy 2017-06-09
# Cars 3 2017-06-16
# Fifty Shades Darker 2017-02-10
# Murder on the Orient Express 2017-11-10
# xXx: Return of Xander Cage 2017-01-20
# The Lego Batman Movie 2017-02-10
# Annabelle: Creation 2017-08-11
# Wonder 2017-11-17
# Ferdinand 2017-12-15
# Split 2017-01-20
# Blade Runner 2049 2017-10-06
# Get Out 2017-02-24
# Baahubali 2: The Conclusion 2017-04-28
# Alien: Covenant 2017-05-19
# Paddington 2 2018-01-12
# Baby Driver 2017-06-28
# Valerian and the City of a Thousand Planets 2017-07-21
# Geostorm 2017-10-20
# The Emoji Movie 2017-07-28
# A Dog's Purpose 2017-01-27
# Smurfs: The Lost Village 2017-04-07
# The Shape of Water 2017-12-01
# Pitch Perfect 3 2017-12-22
# Daddy's Home 2 2017-11-10
# The Post 2018-12-22
# Baywatch 2017-05-25
# The Hitman's Bodyguard 2017-08-18
# John Wick: Chapter 2 2017-02-10
# Ghost in the Shell 2017-03-31
# Darkest Hour 2017-11-22
# King Arthur: Legend of the Sword 2017-05-12
# The Foreigner 2017-10-13
# Power Rangers 2017-03-24
# Girls Trip 2017-07-21
# American Made 2017-09-29
# A Bad Moms Christmas 2017-11-01
# Happy Death Day 2017-10-13
# Captain Underpants: The First Epic Movie 2017-06-02
# The Lego Ninjago Movie 2017-09-22
# The Commuter 2018-01-12
# The Dark Tower 2017-08-04
# Jigsaw 2017-10-27
# Life 2017-03-24
# Atomic Blonde 2017-07-28
# The Shack 2017-03-03
# Tiger Zinda Hai 2017-12-22
# Going in Style 2017-04-07
# Rings 2017-02-03
# Lady Bird 2017-11-03
# The Nut Job 2: Nutty by Nature 2017-08-11
# American Assassin 2017-09-15
# Victoria & Abdul 2017-09-22
# The Mountain Between Us 2017-10-06
# The Star 2017-11-17
# How to Be a Latin Lover 2017-04-28
# 47 Meters Down 2017-06-16
# Snatched 2017-05-12
# My Little Pony: The Movie 2017-10-06
# Molly's Game 2017-12-25
# All the Money in the World 2017-12-25
# The Big Sick 2017-06-23
# All Eyez on Me 2017-06-16
# Downsizing 2017-12-22
# Logan Lucky 2017-08-18
# Boo 2! A Madea Halloween 2017-10-20
# Phantom Thread 2018-12-25
# Rough Night 2017-06-16
# Flatliners 2017-09-29
# Mother! 2017-09-15
# Wind River 2017-08-04
# The Snowman 2017-10-20
# Gifted 2017-04-07
# Loving Vincent 2017-09-22
# Call Me by Your Name 2017-11-24
# Fist Fight 2017-02-17
# The Circle 2017-04-28
# Diary of a Wimpy Kid: The Long Haul 2017-05-19
# Home Again 2017-09-08
# Hostiles 2018-12-22
# Kidnap 2017-08-04
# The House 2017-06-30
# Sleepless 2017-01-13
# The Bye Bye Man 2017-01-13
# The Disaster Artist 2017-12-01
# The Beguiled 2017-06-23
# CHIPS 2017-03-24
# A Cure for Wellness 2017-02-17
# Only the Brave 2017-10-20
# The Zookeeper's Wife 2017-03-31
# Father Figures 2017-12-22
# The Death of Stalin 2018-03-09
# Wish Upon 2017-07-14
# Detroit 2017-07-28
# The Glass Castle 2017-08-11
